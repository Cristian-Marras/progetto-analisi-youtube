# %%
import json
import time
import os
import networkx as nx
from itertools import combinations
from datetime import datetime


#build permette di definire il punto di accesso da cui invocare i diversi endpoint delle YouTube API.
from googleapiclient.discovery import build

# %%
API_KEY = os.environ.get("API_KEY")

# %%
DEVELOPER_KEY = API_KEY
YOUTUBE_API_SERVICE_NAME = 'youtube'
YOUTUBE_API_VERSION = 'v3'

# %%
youtube = build(YOUTUBE_API_SERVICE_NAME, YOUTUBE_API_VERSION, developerKey = DEVELOPER_KEY)

# %%
with open('videoToCommentersFinal.json', 'r') as f:
    videoToCommentersFinal = json.load(f)

# %%
videoToCommenters = videoToCommentersFinal

# %% [markdown]
# ### Aggiungo attributi ai nodi: TITOLO, LIKES, VIEWS.

# %% [markdown]
# Salviamo la data di pubbliczione nel dict non come datetime ma come stringa (perché nel dict non si possono mettere i datetime). Nella fase di analisi la ritrasformeremo in datetime con datetime.strptime

# %%
def get_video_details(video_id):
    request = youtube.videos().list(
        part="snippet,statistics",
        id=video_id
    )
    response = request.execute()

    # Estrai i dettagli del video dalla risposta
    video_details = response['items'][0]
    title = video_details['snippet']['title']
    published_at = datetime.strptime(video_details['snippet']['publishedAt'], '%Y-%m-%dT%H:%M:%SZ')
    likes = int(video_details['statistics'].get('likeCount', 0)) 
    views = int(video_details['statistics'].get('viewCount', 0))

    return {
        'title': title,
        'published_at': published_at,
        'likes': likes,
        'views': views
    }

# %% [markdown]
# scrivo in altro modo aggiungendo controllo eccezioni

# %%
from datetime import datetime

def get_video_details(video_id):
    try:
        request = youtube.videos().list(
            part="snippet,statistics",
            id=video_id
        )
        response = request.execute()

        # Controlla se la risposta contiene elementi
        if 'items' in response and response['items']:
            # Estrai i dettagli del video dalla risposta
            video_details = response['items'][0]
            title = video_details['snippet']['title']
            published_at = datetime.strptime(video_details['snippet']['publishedAt'], '%Y-%m-%dT%H:%M:%SZ')
            likes = int(video_details['statistics'].get('likeCount', 0)) 
            views = int(video_details['statistics'].get('viewCount', 0))
            comment_count = int(video_details['statistics'].get('commentCount', 0))  # Aggiungi il numero di commenti

            return {
                'title': title,
                'published_at': published_at,
                'likes': likes,
                'views': views,
                'comment_count': comment_count  # Aggiungi il numero di commenti
            }
        else:
            print(f"I dettagli per il video con ID {video_id} non sono stati trovati.")
            return None
    except Exception as e:
        print(f"Si è verificato un errore durante l'ottenimento dei dettagli per il video con ID {video_id}: {e}")
        return None

# %%
# Ciclo attraverso ogni video nel dizionario e aggiungi i dettagli del video
for video_id, commenters in videoToCommenters.items():
    details = get_video_details(video_id)
    # Converti la data di pubblicazione in formato stringa
    details['published_at'] = str(details['published_at'])
    # Creo una nuova struttura dati contenente i dettagli del video e la lista di commentatori
    video_details = {
        'commenters': commenters,
        'details': details
    }
    # Aggiungi questa nuova struttura dati al dizionario videoToCommenters
    videoToCommenters[video_id] = video_details

# Salva il dizionario aggiornato come un file JSON
with open('videoToCommenters_with_details.json', 'w') as json_file:
    json.dump(videoToCommenters, json_file, indent=4)

# %%
with open('videoToCommenters_with_details.json', 'r') as json_file:
    videoToCommenters_with_details = json.load(json_file)

# %%
videoToCommenters_with_details
# Out:
# {'tem_iCzlHbI': {'commenters': [['@tintoriapodcast', 'Evvai'],
#    ['@gabrielefregni',
#     'Certo che i fan di tintoria sembrano un&#39; accozzaglia di imbecilli a giudicare dai commenti, non so se è perché hanno tredici anni o perché sono di Roma🤔'],
#    ['@emanuelet1366',
#     'Ma che cazzo dicono che coi tedeschi si parla solo di nazismo. Che provinciali ahah'],
#    ['@julianhowald6268', 'Quando la puntata con fedez?'],
#    ['@blue00magic99',
#     'E niente, non bastano Tinti e Rapone a evitare il grattugiamento di scatole nel guardare questo podcast'],
#    ['@pinomuscatelli6378', 'Tintoria &gt; Muschio selvaggio'],
#    ['@skyall2261', 'Ahahahahahhaha la puntata più divertente di tutte!😂😂'],
#    ['@DP-pf9ky',
#     '<a href="https://www.youtube.com/watch?v=tem_iCzlHbI&amp;t=2436">40:36</a><br>fritz da cat <br>o<br>catz the fritz?'],
#    ['@andrealarosa5682', 'Fate conto che Muschio Selvaggio sia il web...'],
#    ['@angelorossi2471',
#     'Io non ci sto capendo più niente, ma chi conduce muschio selvaggio?'],
#    ['@mattiapatruno7106', 'Miglior puntata a mani basse'],
#    ['@andycrxvti',
#     'Quando invitate in studio Iovino che ci racconta dell’aggressione???'],
#    ['@BjornWrt', 'Lucian Freud era il nipote'],
#    ['@lorippn', 'Incredibile: Tinti e Rapone visti non di profilo… 😮'],
#    ['@massimocometto7474', 'grandi puntata top'],
#    ['@robertoferracci8414', 'In Ucraina c&#39;è normalità, a Gaza no'],
#    ['@Squalo_Pasqualo',
#     'L&#39;orto di Penelope... 🤣🤣🤣☠️<br>Tinti the best ❤️'],
#    ['@DavideP89',
#     '...e così figliolo è nata la leggenda di Alessandro Borghese superdotato...'],
#    ['@loggo6164', 'Perché è indagato Luis?'],
#    ['@valeriogiorgiani728',
#     'La faccia di Tinti che si vede nominare Feltri come modello di comicità è un qualcosa di straordinario'],
#    ['@MastroPuddu',
#     'Non avete l&#39;umorismo giusto per i griffin..le prime dieci stagioni si mettono in culo South park e compagnia bella'],
#    ['@fabrisiogamer8960',
#     'Godo troppo a sapere che fate la metà delle views di Marra e Fedez'],
#    ['@EvaMiusik',
#     'Se venissero invitati ad almeno un podcast a settimana, così c&#39;è una puntata in più di Tintoria :)'],
#    ['@smacchers', 'Sto a volà, giuro'],
#    ['@ildalek4635', 'Futurama&gt;Simpsons<br>I Griffin&gt;American Dead'],
#    ['@Bosferatus',
#     'Avete ragione sui simpson, sono meglio dei griffin però dobbiamo ricordare questo:<br><br>Siamo a scuola nel laboratorio di scienze e Mag e Neil l’ebreo stanno dissezionando un maialino.<br>Neil: non posso dissezionare questo maiale signor Kingman è contro la mia religione!<br>Kingman: credimi Neil, non è il massimo neanche per un maiale toccare un ebreo'],
#    ['@josephleonardlee8613', 'Adoro i crossover'],
#    ['@giodydapozzo6572', 'Daniele Tinti sex symbol'],
#    ['@antoluve1113', 'Nei Simpson i personaggi muoiono con i loro doppiatori'],
#    ['@antoluve1113', 'Come si può non avere visto la puntata con Magalli?'],
#    ['@simonelorenzoni',
#     'C&#39;è uno spoiler su un Tintoria con la Bignardi o son desto?'],
#    ['@canemorto1142',
#     'Chef Borghese ha il cazzo largo e puzzolente anche se lo lava spessissimo, è proprio uno di quei cazzi che la ragazzina 2d nel doujinshi dice &quot;its stinky...why am I so attracted?&quot;'],
#    ['@canemorto1142', 'Se dovesse arrivare la Cina: eccoci qua'],
#    ['@ignoranzatop5196', '4 comunisti'],
#    ['@labepi', 'Puntata diesel, parte soporifera e finisce scoppiettante'],
#    ['@ic2127',
#     '<a href="https://www.youtube.com/watch?v=tem_iCzlHbI&amp;t=2227">37:07</a>  ahahahhahahahahahahhahahahahahah mortah<br>È vero Vannacci fa ridere tantissimo'],
#    ['@gangantirione',
#     'mai visto rapone cosi lucido ed ispirato in 200 puntate di tintoria'],
#    ['@benvenutogiandolfi7910',
#     'Posso dire un pò deluso dall&#39;assenza di battute sulla questione Fedez-Luis?'],
#    ['@oscar98653210',
#     'Prossimamente su Tintoria &quot;Cagare in Trincea&quot; <a href="https://www.youtube.com/watch?v=tem_iCzlHbI&amp;t=4436">1:13:56</a>'],
#    ['@alfredocorbelli603', 'VENI VIDI VICI, TINTORIA CAPVT MUNDI'],
#    ['@SaittaRudy', 'Tintoria selvaggia &lt;3'],
#    ['@emmepicci',
#     'Adoro Tinti e Rapone ma non sono riuscito a finire di vedere questo video... una noia incredibile.'],
#    ['@danielkasa9721', 'Prossimo, Zeb89'],
#    ['@Ciro919',
#     'ma presentare gli ospiti? date per scontato che li conoscono tutti?'],
#    ['@user-eb2wv9wk3n', 'PEGGIOR PUNTATA'],
#    ['@ErmannoAndreaFunari',
#     'bellissimo podcast....da un po&#39; di tempo.....'],
#    ['@leonardotrevisan2538', 'A quando un episodio con Caparezza?'],
#    ['@fracangia',
#     'Ma è Muschio Selvaggio che ospita i protagonisti di Tintoria o è una puntata di Tintoria che ospita i protagonisti di Muschio Selvaggio?'],
#    ['@zaimon2588', 'Prossimo ospite Andrew Tate'],
#    ['@paridecallari3094',
#     'minuto 4.56 e Tinti ha gia preso in mano il podcast e fa domande gli hosts. Applauso!'],
#    ['@canemorto1142',
#     'Non credo che la satira abbia impatto sulla realtà nel senso del cambiamento, ma che invece MANTENGA uno status quo che se non ci fosse farebbe scivolare la realtà &quot;democratica&quot; più in basso'],
#    ['@canemorto1142',
#     'Non ti possono togliere niente tranne, letteralmente, la libertà. Cioè le multe si posso non pagare ecc, ma LA LIBERTÀ è tipo l&#39;unica cosa che ti possono togliere 🤭🧀😎🍑'],
#    ['@ugugublu2951',
#     '<a href="https://www.youtube.com/watch?v=tem_iCzlHbI&amp;t=3963">1:06:03</a> certo, perché per i tedeschi l&#39;italiano era una lingua totalmente aliena.'],
#    ['@nic-ci_66-77',
#     'Ridico che ho letto che per alcuni intellettuali il Mein Kamf è uno dei libri di politologia più significativi del 900. Il che mi ha molto sorpreso perchè ero abituato a pensare a una cagata'],
#    ['@JOGAMINURA',
#     'Bellissima puntata, tutti bravi... Ma Tinti è il padrone della scena, spacca i culi...'],
#    ['@giocatorezero478', '&quot;Falla te mentre...&quot;'],
#    ['@GerusalemmeCristiana', 'Futurama numero uno.'],
#    ['@dennyschiac09', 'Invece candidare la Salis non e^ comico vero?'],
#    ['@drunkenfox1004',
#     'È incredibile come ho perso 20 euro per strada e mentre mi incazzavo ho visto questo episodio e mi sono solo arrabbiato di più'],
#    ['@pierpaologiamello',
#     'Purtroppo l&#39;asticella si é abbassata ancora di più da quando lupus ha iniziato a fregarsene, peccato ero così contento fosse tornato.'],
#    ['@86canc',
#     'Solo tinti e rapone potevano farmi guardare una puntata di muschio'],
#    ['@edoardottt',
#     '<a href="https://www.youtube.com/watch?v=tem_iCzlHbI&amp;t=125">2:05</a> questa non l&#39;ho capita 😅'],
#    ['@fabiobaretta55',
#     'Figa se tagliaste tutte le stronzate che dice luis vi rimarrebbero 15 minuti di puntata'],
#    ['@Sighebab', 'Martin che ha le sigarette nel barattolino :D'],
#    ['@simoneagresti3691',
#     'Anche mio nonno diceva, letteralmente, di &quot;non aver mai sparato un colpo&quot;. E ci ho sempre creduto, fino ad oggi.'],
#    ['@user-uw7uv6xt3f', 'sto crepando🤣🤣🤣'],
#    ['@dirtymusicassette',
#     '<a href="https://www.youtube.com/watch?v=tem_iCzlHbI&amp;t=4970">1:22:50</a> lascio questo messaggio per la polizia scientifica. Se troverete il mio corpo e controllerete la cronologia, forse troverete questo timestamp.<br>Mi accingo a riguardarlo un ultima volta ma non so se sopravvivrò.'],
#    ['@lil_tod7898',
#     'Quando uscì muschio e scoprii Martin pensavo fosse una persona intelligente, poi ho letto dei libri che non sono romanzi e sentirlo parlare mi innervosisce. Borioso ignorante, fa la parte del mistico ma non ha idee'],
#    ['@francescosacco5114', 'Finalmente quel giorno è arrivato'],
#    ['@Lynch___',
#     'mi tocca guardare un episodio di un podcast che non è tintoria. non ero abituato.'],
#    ['@massimonoce7186',
#     'Questi due ragazzi passano dal dire banalità a vaccate sesquipedali senza soluzione di continuità. Riescono a rendere noiosi pure Tinti&amp;,Rapone. Saranno bravi forse a fare altro ma i podcast non sono davvero cosa loro'],
#    ['@nicolapersico2212', 'Bel PORCAST'],
#    ['@gabriellaesposito5182',
#     'Martin ti si ama ma a Gaza nessuno va a scuola o gioca a calcio o vive la normalitá'],
#    ['@acidboy4947',
#     'sono talmente fan di tintoria che mi so visto il podcast di due infami bolognesi'],
#    ['@andreavalentini1648', 'Bellissima puntata'],
#    ['@raff4el3',
#     '&quot;100% con  la tecnologia di oggi Ghandi mandava la foto del cazzo a tutte&quot; .Cit<br>Sono venti minuti che rido da solo mentre lavo i piatti'],
#    ['@davidelinn',
#     'Il livello di conduzione del podcast di Luis e&#39; cosi&#39; amatoriale che nemmeno gli episodi di Tintoria durante il Covid'],
#    ['@v11751', 'Ma sono Moretti?'],
#    ['@EleanorAbernathy99', 'I re Mida del podcasting italiano❤'],
#    ['@vincentvega3961', 'posso dire? una bella puntata del ca770'],
#    ['@Raffaele_Magliulo', 'La pausa pipì di Tinti è stata tagliata?'],
#    ['@riccardoonline435',
#     '<a href="https://www.youtube.com/watch?v=tem_iCzlHbI&amp;t=4338">1:12:18</a> Luis fan della &quot;Resistencia&quot; di Pablo Escobar al fisco. Battuta che è stata sottovalutata.'],
#    ['@LucaAlbertoTagliaferro-th3ph',
#     'Chiamate Gemitaiz a muschio selvaggio sarebbe molto interessante'],
#    ['@saimon9987', 'Ma che ridere questa puntata 😂😂'],
#    ['@roccobot',
#     'Madonna Luis uno sbalzo di genio ogni lustro ma poi livello seconda elementare'],
#    ['@Gieffe4491', 'Ma l&#39;inizio sembra il processo di Kafka ahah'],
#    ['@aaa-mb2ii',
#     'ora che non c&#39;è fedez a stuprare la cultura è parassitare follower altrui è diventato guardabile.'],
#    ['@axelspinelli7539',
#     'Comunque sto nuovi nuovo corso di Muschio a me fa impazzire che pare sempre di rivivere un dabato sera ai parchetti con gli amici a 17 anni che per altro sono i momenti più belli della mia vita.'],
#    ['@Max-nn8kr',
#     'Vedere Tintoria a muschio selvaggio è una cosa inimmaginabile… tipo Totti alla Lazio, Carlo Conti impallidito oppure Salvini che dice cose intelligenti.'],
#    ['@danielepapi3724', 'ma dov&#39;è FedeX ?'],
#    ['@federicoderqui7543',
#     'Rapone molto simpatico, Tinti argutissimo. Il podcast riesce da solo senza sforzo alcuno. Bravi'],
#    ['@yvngmirvti6676', 'panettata'],
#    ['@zaradrum1345',
#     'Mi fate rimpiangere perfino fedez… <br>Siete improponibile, siete l’anti podcast per eccellenza. <br>La fortuna che avete  grandi ospiti, altrimenti il declino sarebbe più veloce, ma arriverà purtroppo.'],
#    ['@cecilia5043',
#     'Sono 2 gg che rido Luissssss.....  la risposta di Tinti <br>Continui a ridere col Borghi Borghese <br><br>Ragazzi siete il top!'],
#    ['@riccardocecchetti7651',
#     'Qual è il tuo rapporto, se ce l’hai, col Muschio?'],
#    ['@lucaferri7626',
#     'se solo ci fosse un modo per vedere una puntata di muschio senza lasciare tracce nella rete, in modo da non dovermene vergognare tra 10 anni con i miei futuri figli'],
#    ['@Emi-cd4yj', 'Che bellezza'],
#    ['@Giuseppe.pe1710',
#     'La puntata di tintoria con Luis e Martin, è una delle più divertenti. Tra flight radar, picchiare bambini e le amnesie di Luis, fu una grande chiacchierata.'],
#    ['@aristidequercetti7587', 'Ma dove sono Fedez e Marra ?😮'],
#    ['@picc7797',
#     '<a href="https://www.youtube.com/watch?v=tem_iCzlHbI&amp;t=2225">37:05</a> il tipo è rimasto al 1990,oggi è proprio la sinistra a discriminare,ad imporre le idee,a censurare ogni cosa se non è il linea'],
#    ['@locosystem', 'Ma chi spernacchia col naso?'],
#    ['@user-sm1wx7or5o', 'Finalmente della qualità'],
#    ['@DeedraS.', 'Cosa chiedere di più 🎉🎉🎉❤'],
#    ['@xstefino01', 'C&#39;è un po&#39; di puntata in questo cazzeggio.'],
#    ['@cosimonetta545',
#     'L&#39;intro di Stefano è degna di Radio Radicale, per timbrica ed &quot;entusiasmo&quot;'],
#    ['@LorenzoCaranzi',
#     'Il discorso su Bill Hicks fatto da Daniele e Stefano è molto lucido e preciso. bravi come sempre!'],
#    ['@LucaGhishFragapane',
#     '<a href="https://www.youtube.com/watch?v=tem_iCzlHbI&amp;t=1974">32:54</a> Luis che continua a ripetere dell&#39;indagine è l&#39;ironia della sorte, le manie di protagonismo che criticava in Fedez adesso le ha lui.<br>La differenza sta nella qualità e particolarità degli ospiti che portava il cantante, con Luis il livello è ben diverso e si arriva a parlare del divertimento legato alle scorregge senza neanche abbassare l&#39;asticella. Luis, (molto) poco ma (tutto sommato, relativamente) buono.'],
#    ['@aldocaccamo6186',
#     'pazzesco a ogni intervento di martin si crea un silenzio imbarazzato per la banalità di quello che dice'],
#    ['@RCBMEDIAREAL', 'Ma che bello! Bravi ragazzi 👏🏼'],
#    ['@paoloiuliano3321',
#     'Tocco di classe di Martin che simula o rumori di Tintoria sbattendo ogni tanto la birra sul tavolo.'],
#    ['@fra_n_z',
#     'Menomale che vostro nonno non è stato sparato altrimenti oggi non ci sarebbe stato Muschio Selvaggio 💚'],
#    ['@mariachiaraporciello6684', 'La sigla è insopportabile'],
#    ['@vespa19',
#     'Ascoltato solo per Tinti e Rapone: Posso dire ma che palle sti 2 conduttori? Ah non posso? Non ho nulla contro di loro, ma mi fanno cascare le palle.'],
#    ['@raff4el3',
#     '<a href="UCkszU2WH9gy1mb0dV-11UJg/m8MfY4jbFsWJhL0PyouA2Ak"></a>'],
#    ['@Jeezyy739',
#     'È senza ulteriori indugi che siamo arrivati alla puntata num.... Ah no 😂<br>Tintoria top podcast in Italia'],
#    ['@Chriseyasuo',
#     '<a href="https://www.youtube.com/watch?v=tem_iCzlHbI&amp;t=645">10:45</a> Mentalità senza alcun senso. Si fa sport per vivere MOLTO meglio per tutta la vita non per &quot;farsi bello alla morte&quot;. A meno che sei Kobe Bryant che è morto a 40 anni in elicottero invecchierai normalmente come tutti ma invecchierai BENE. C&#39;è un enorme differenza Martin dai su non dire cagate da depresso cronico se non fai sport vivi male per tutta la seconda metà della tua vita che tra l&#39;altro si accorcia notevolmente....bisogna pensare che si muore a 90 anni  e puntare ai 100 quindi il corpo non sarà &quot;bello per la morte&quot; sarà vecchio ma sano....'],
#    ['@shareyourpassion2255',
#     'Fanbase di Tintoria strong come quella di Taylor Swift'],
#    ['@ataru2003', 'Ma Rapone ha la maglietta di Dragonball?'],
#    ['@andreadragoni3498',
#     'Grandi, anche mio nonno disertore. Stava con la regia marina in Corsica. Dopo l&#39;armistizio il comandante ha detto a lui e a tutti i suoi compagni di svignarsela quella notte per le bocche di Bonifacio. Mio nonno poi mi sembra abbia trafficato con documenti falsi o rubati per arrivare a napoli dalla Sardegna.'],
#    ['@ciroviscardi276', 'crossover di un certo livello'],
#    ['@nicash70',
#     'A gaza dubito che inbambini stiano giocando a a calcio e andando a scuola...mi fate schifo!'],
#    ['@Frikk_out', 'Oggi non si spaccano bicchieri'],
#    ['@AngeloconlaG',
#     '<a href="https://www.youtube.com/watch?v=tem_iCzlHbI&amp;t=177">2:57</a> &quot;idealemente&quot; quindi la puntata con BabyK e Geopop come fu pensata? cosa originò l&#39;accoppiata?'],
#    ['@arturotaglialatela5412', 'Ho trovato 100 euro a terra. Dichiarati?'],
#    ['@TheStrayToaster',
#     'Col finale su Borghese prima volta in vita mia che piango dal ridere su YouTube'],
#    ['@morganaRockBand', 'Ah oggi ci sono 2 conduttori!'],
#    ['@sarad3833', 'Team Tinti, i Griffin fanno riderissimo ✊🏻💜'],
#    ['@cacacacacca92', 'Ma fedez? Si è tolto dai coglioni per sempre?'],
#    ['@NicolaDaniele',
#     'Se non sbaglio nei simpson, quando muore un personaggio, è perchè il suo doppiatore è morto, e una scelta che fanno da tanti anni, non solo Edna, anche gengive sangunanti, il prof. Monroe, troy mclure(non so se é scritto gisto) ecc....'],
#    ['@francescocoi8264', 'Confermato Surry co-host quindi?'],
#    ['@mattiabisinella7612',
#     'invitate un intellettuale o qualcuno che sa dire qualcosa seno viene fuori un discorso da bar irrilevante, crea disinformazione, annoiare la mente.'],
#    ['@punkdesigner8159', 'puntata di Tintoria con un altro nome'],
#    ['@italianguy9449',
#     '<a href="https://www.youtube.com/watch?v=tem_iCzlHbI&amp;t=570">9:30</a> hai detto calcetto?'],
#    ['@salvpan', 'Prossimo ospite di Tintoria, Daria Bignardi'],
#    ['@simplymau142', 'ZEB89 tra i prossimi invitati'],
#    ['@bellacome', 'Signori e signore muschio selvaggio applauso!'],
#    ['@jairoalexandervicinanza18', 'La sinistra  fa proprio ridire…'],
#    ['@giadagreco5365', 'Rapone ❤'],
#    ['@elenafragnoli1215',
#     'Ciao seguaci di Muschio Selvaggio, grazie x l&#39;ospitalità e scusate l&#39;invasione dei nostri commenti &quot;Tintorici&quot;😁<br>... la puntata in cui vi ospitiamo noi é la 132, se vi va di guardarla❤...<br>Al prossimo gemellaggio 😊😊🤸'],
#    ['@topafra',
#     'Io ci provo ogni volta ma è veramente inascoltabile questo podcast. L’unica puntata interessante è stata la scorsa perché effettivamente l’ospite aveva qualcosa da dire di interessante e ha tenuto su tutta la puntata.'],
#    ['@Math-Phill',
#     'Non sentire i bicchieri di birra che cadono mi destabilizza parecchio 😢'],
#    ['@subcomandantemarcos9294', 'NOVVVABBBÉ'],
#    ['@ceressable', '❤❤'],
#    ['@albatros2155',
#     'Ma e possibile che dove vanno vanno alla fine  riescono a parlare di Mussolini e i suoi amici.<br>Fantastico'],
#    ['@coencoen.',
#     '&quot; fine puntata:<br>luisburt prende lo skate da sotto il tavolo ci salta suh <br>martinlisa prende il sassofono da dietro la sedia e ci soffia suh<br>danielhomer si gratta la pancia prende la birra dal tavolo e la leva suh<br>raponemarge prende un fermaglio da capelli luccicante e se lo infila dalla chioma in suh<br><br>fuori campo si sente maggie ciucciare sempre più forte sempre più suh<br><br>la fine sullo schermo sale suh &quot;'],
#    ['@stica8935', 'TINTORIA❤'],
#    ['@Il_Poetto_Maledettoh',
#     'Luis Sal, con il viso segnato dall&#39;ombra,<br>davanti ai giudici, il cuore in subbuglio,<br>milioni di euro, l’accusa lo adombra,<br>un processo lungo, in un vortice oscuro.<br><br>Dieci anni, forse più, a danzare nel dubbio,<br>la giustizia italiana come un miraggio lontano,<br>nel suo cuore non c&#39;è spazio per l&#39;illusione,<br>solo il timore di perdere ogni cosa a mano a mano.<br><br>Ma Luis, con uno sguardo ribelle e amaro,<br>non si arrende alla morsa del destino,<br>trova un rifugio nel pensiero, raro,<br>evadere meglio... non col denaro, ma col sogno divino.<br><br>Al suo fianco, Martín, il fratello fedele,<br>cerca di guidarlo verso la liberazione,<br>“Lascia le brame materiali, le catene crudeli,<br>trova pace nella mente, la vera soluzione.”<br><br>Luis ascolta, il cuore in tumulto,<br>ma le parole di Martín sono come un faro,<br>un lume che rischiara l’animo adulto,<br>che cerca nell&#39;invisibile, il suo riparo.<br><br>Il mondo reale lo opprime, lo stringe,<br>ma la mente sua vola oltre l&#39;orizzonte,<br>nel regno delle idee, dove il tempo non vince,<br>là trova pace, lontano da ogni fronte.<br><br>E così, mentre la giustizia lenta marcia,<br>Luis Sal evoca visioni di un futuro sereno,<br>dove la libertà è il suo solo paravento,<br>un evasore di sogni, senza catene, né freno.'],
#    ['@robertaranzetti6966',
#     'non era ancosa uscita la saga di Michael di Iris Babilonia  =)'],
#    ['@valeriop82',
#     'la morte di Larry nei Simpson ha fatto notizia perchè Larry è uno dei più vecchi personaggi dei Simpson'],
#    ['@pietro0000000', 'va bene tutto ma cortesemente cambiate la sigla dai'],
#    ['@gabrieleronzini',
#     'luis si lamentava del fatto che Fedez usasse il podcast come un suo spazio, sono al min <a href="https://www.youtube.com/watch?v=tem_iCzlHbI&amp;t=1380">23:00</a> e parla sempre della sua questione legale... 😅'],
#    ['@Tavoletta.', 'Dovreste invitare Side Baby'],
#    ['@Tavoletta.',
#     'Fedez sta proprio bene con i capelli lunghi e finalmente ha smesso di interrompere gli ospiti'],
#    ['@valpre03', 'Grande curiosità per la puntata con borghese'],
#    ['@user-rw8uq4ko9t', 'Meglio Fedez dasolo'],
#    ['@christianbay5100', '4 bambini che parlano as<br>Unmicrofono'],
#    ['@photoshockce', 'Questi due uomini hanno cambiato la mia vita. Evvai'],
#    ['@valpre03',
#     'Benvenuti nella sezione commenti dominata dai seguaci di Tintoria<br>APLLAUSO'],
#    ['@gabrieleanello68',
#     'la prima puntata interessante da quando il podcast e tornato in mano a Luis'],
#    ['@user-qv1ov9pu9x',
#     'Ottima puntata perché sembra una puntata di tintoria'],
#    ['@nicolobuceti8160', 'Grazie'],
#    ['@filippoedobor6046',
#     'Che bello che nei commenti ci sono solo fan di tintoria'],
#    ['@mhanz2474', 'Che imbarazzo'],
#    ['@zippoluca1288',
#     'Tinti: La destra in Germania gode di estremissima salute'],
#    ['@alessio0007', 'Grande fedez'],
#    ['@fabbriandrea0',
#     'Bicchiere che cade a <a href="https://www.youtube.com/watch?v=tem_iCzlHbI&amp;t=2270">37:50</a>…Applausi'],
#    ['@Snakeita901', 'Alla fine l&#39;avvocato l&#39;ha chiamato Luis'],
#    ['@danielbertocchi3266', 'Luis non sei Anas e non lo sai fare'],
#    ['@francescociaccio5832',
#     'Un uomo che spiega qualcosa a una donna si chiama mansplaining, un uomo che spiega qualcosa a un altro uomo si chiama podcast'],
#    ['@nicoladc89',
#     'Con il lockdown noi vecchietti over 30 abbiamo capito che alla fine si sta bene anche a casa.'],
#    ['@RezzaFio', 'Se te va fallo npodcast Danielí'],
#    ['@squass96',
#     'Martin per favore salva questo podcast da Luis, sta andando tutto a rotoli da due mesi…'],
#    ['@lucadecol1967', 'ma quando ci portate il brasilianoooooo'],
#    ['@lorenzomirto2443',
#     'Non è certo grazie alla mamma e all&#39; avvocato se siamo arrivati alla puntata 155'],
#    ['@edofarmer812', 'È bastato un click'],
#    ['@gionadibenedetto6321',
#     'Ma Luis che rimproverava (a ragione) fedez che parlava sempre di se.. ha passato i primi 10 min a parlare di se 😂'],
#    ['@miillumina1170', 'Che piega ansiogena ha preso il finale?'],
#    ['@gianlucatrainotti8512', 'Attendiamo STEFANO MANCUSO🌱'],
#    ['@dennyricci',
#     'Che bella la maturità di un fratello maggiore nel calmare e riprendere i discorsi...'],
#    ['@andreacaralli9467', 'Martin filosofo: il tempo è una carnevalata'],
#    ['@matteob2207', 'Sempre peggio secondo me……'],
#    ['@GregBreak', 'Ma quanto sono inutili i discorsi che fanno?'],
#    ['@ahmacche',
#     'A parti invertite quando parlavano di videogiochi Rapone avrebbe detto &quot;Che te stai a giocà?&quot;'],
#    ['@massimomoi',
#     'Comunque Luis criticava fede per l&#39; ego..ma i primi 8 minuti ha parlato di sé'],
#    ['@ACETOakaBELTA', 'Come mai Luis è sotto processo?'],
#    ['@gianlucacesaretti8886', 'Grandi il🔝del🔝'],
#    ['@irandagi', 'Like immediato sulla fiducia'],
#    ['@hunchososa9971',
#     'Che palle martin mi fa venire voglia di svegliarmi elegante in un letto di mogano'],
#    ['@MrKobag', 'Non sento bicchieri rompersi, come mai?'],
#    ['@batroberto3369',
#     'Porco2, torno a vedere sta merdata di podcast solo per i miei idoli'],
#    ['@paolaspinolo857',
#     'Per ogni domanda sulla questione Michael Jackson guardate gli ultimi due video di Iris Babilonia!!!'],
#    ['@pietropasqualetti8725',
#     'Luis, ti prego, fai pace con Fedez. Assieme,, Muschio Selvaggio sarebbe una potenza nel web'],
#    ['@abcun',
#     '<a href="https://www.youtube.com/watch?v=tem_iCzlHbI&amp;t=3290">54:50</a> Martin mi meraviglio di te! Il singolare di media è medium.'],
#    ['@anamdainti193',
#     'Calunniare Michael Jackson dopo la morte pero&#39; mi sembra un po&#39; troppo. Tutte le accuse rivoltegli negli anni sono state ufficialmente ritenute senza alcun fondamento. Nel 2024 ancora c&#39;e&#39; gente che accosta Jackson con la pedofilia....    Siamo a sposto !'],
#    ['@Sandrino88', 'Si'],
#    ['@max.brb00', 'fanno mega ridere i nomi dei segmenti del video'],
#    ['@vitocandido1210',
#     '&quot;Il porto di Penelope&quot;. Date una medaglia a quest&#39;uomo.'],
#    ['@AlfredoDam',
#     'Siamo arrivati alla 155esima puntata non certo per il nostro ritmo incalzante, non certo per gli argomenti esposti, ma per i nostri incredibili ospiti...'],
#    ['@andreatinterri8880', 'Boooooooooom'],
#    ['@aminemoughanime6494',
#     '<a href="https://www.youtube.com/watch?v=6iwPS1RzJmw">https://youtu.be/6iwPS1RzJmw?si=d8vddxI9Qi5LziRJ</a>']],
#   'details': {'title': 'Ep.155 Podcast di Stato con Daniele Tinti e Stefano Rapone - Muschio Selvaggio Podcast',
#    'published_at': '2024-05-27 12:00:59',
#    'likes': 7950,
#    'views': 237416,
#    'comment_count': 483}},
#  'DzLjwWZjr5w': {'commenters': [['@ben3xe',
#     'Il cicap fa divulgazione scientifica 🤣🤣🤣🤣 <br>Ma mi faccia il piacere!!! 🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣'],
#    ['@emanuelet1366',
#     'L&#39;arroganza con cui certi &quot;scienziati&quot; si arrogano di avere la veritá é diventato ormai quasi religioso. Iniziare citando il tema Covid e cambiamento climatico, che sono due tematiche altamente controverse per chiunque sia capace di fare un paio di sillogismi aristotelici, dimostra come la Scienza sia diventata una Religione e ancor di piú da adito e vigore a personaggi e teorie discutibili, proprio perché non é piú in grado di mettere in discussione sé stessa (che tra l&#39;altro sarebbe il metodo scientifico stesso).'],
#    ['@FC-df2qk',
#     'Guarda caso il cicap non ha mai smentito nessuna delle versioni ufficiali. Sarà che quello che ci raccontano è sempre tutto vero? secondo loro si… personalmente trovo questo approccio molto più preoccupante rispetto a ciò che criticano'],
#    ['@biagio6047', 'Ci starebbe invitare Mazzucco a questo punto!'],
#    ['@lucamonti4849', 'riprese dritte pls'],
#    ['@alicecipriani00',
#     'Bellissimo episodio, veramente interessante. Ottimo ospite: molto chiaro ed esplicativo!'],
#    ['@Caslo833',
#     'che schifo che ci si debba ancora parare il culo dai ritardati religiosi e spirituali e che si continui ad assecondarli. &quot;ognuno è libero di credere in ciò che vuole, non fa male a nessuno&quot; FALSO, le credenze infondate delle persone sono alla base di quasi tutti i conflitti della storia dell&#39;umanità.'],
#    ['@vinch1305', 'Ma lui era il mio professore!'],
#    ['@axelingrasso',
#     '<a href="https://www.youtube.com/watch?v=DzLjwWZjr5w&amp;t=3303">55:03</a> hanno detto che &quot;c&#39;è una libreria esoterica qui davanti&quot; <br>Quindi dov&#39;è lo studio di registrazione?'],
#    ['@valentina1852', 'Gesù pensaci tu.'],
#    ['@carmeloneri4985', 'Bellissima puntata ed estremamente interessante'],
#    ['@manse92',
#     'Da fan del podcast non ho trovato un Luis all’altezza del ospite'],
#    ['@nicolasdovidio129',
#     'dalla miniatura sembra l&#39;intervista ad un complottista, invece è tutto il contrario, amici sto guardando l&#39;intervista dopo gli short'],
#    ['@elezampa', 'Più puntate come questa per favore!!!'],
#    ['@davidevasco',
#     '<a href="https://www.youtube.com/watch?v=DzLjwWZjr5w&amp;t=1925">32:05</a> NON si tratta di CHI LEGGITTIMA COSA ma di chi crede senza aver verificato QUALUNQUE cosa... il CICAP dice di aver provato che i fantasmi non esistono ma se nessuno credesse a nessuno, tutti dovrebbero provare a fare il loro stesso test e questi comporterebbe 8 miliardi di test... il riporre la fiducia è un modo di risparmiare del tempo ed energie ritenendo che i &quot;custodi della verità&quot; nel momento in cui si espongono vengano regolati e sorvegliati dai &quot;custodi della LEGALITÀ&quot;... è una catena labile dove appena uno di questi 2 individui usa la sua posizione come dato trampolino per acquisire credito x denigrare il resto tutto si interrompe e quindi hai continui terra piattisti, negazionisti, complottisti, meta-scienziati nella misura in cui OGNUNO PUÒ DIRE CIÒ CHE VUOLE!!! e nella misura in cui non vengono smentiti da coloro di cui ci fidiamo!!!'],
#    ['@davide6763',
#     'Una puntata veramente bellissima e interessante a parer mio'],
#    ['@lauram.5370',
#     'Sono una persona semplice:<br>1) Mi siedo su primi banchi perché sono miope e non vedo un ca**o<br>2) Mi siedo sui posti esterni così non rompo le scatole a nessuno quando mi devo alzare'],
#    ['@Grifondorzo', 'tutto molto bello, tranne il cappello di Luis'],
#    ['@old_piter',
#     'La sindone era in una teca ignifuga durante un incendio nella chiesa dpve stava. Hanno fatto lo stesso procedimento su un lembo di mantello antico e successivamente, all&#39;analisi la datazione risultava alterata'],
#    ['@Illog1c', 'Martin è il direttore artistico'],
#    ['@cippalippadoppiozero', 'muschio selvaggio è tornato... che bello!'],
#    ['@alessandrocavallo4863',
#     'Il cicap è finanziato direttamente dall’America deve sempre proteggere le versioni ufficiali di qualsiasi evento straordinario…<br>Per me sono venduti…<br>Muschio selvaggio sveglia ⏰ !!!!'],
#    ['@violafrera5551',
#     'Però a me era successo di addormentarmi in una stanza e di aver visto in sogno che mi rovesciassero un gioco....<br>Mi svegliai e il gioco venne rovinato'],
#    ['@mariacristinacolombo8695',
#     'Mi sono scoperta “sapiosessuale”. Un’ora di godimento, grazie Muschio Selvaggio, contenuto interessante ❤️'],
#    ['@antoniocosimo374',
#     'al minuto 12.02, dove si parla di sogno/realtà, Eduardo de Filippo su questo tema ci ha scritto una commedia. Si chiama &quot;Le voci di dentro&quot;. È meravigliosa.'],
#    ['@robberto654',
#     'Scusateci se non abbiamo voglia di andare a cercare su Wikipedia la storia dell&#39; ospite che voi avete scelto. Se non si introduce la persona che parla le sue parole perdono di valore e credibilità, allora invece di cercare personalità diverse e interessanti tanto varrebbe ospitare il primo che passa. Senza un cappello introduttivo risultano inutili chiacchiere da bar tra sconosciuti (cosa che fortunatamente non è successa in questa puntata perché vi siete degnati di &quot;lavorare&quot;)'],
#    ['@antonellostrippoli6926',
#     'Fink deep e puc your Maney were your maut is.'],
#    ['@mattiacristiani5391', 'Bellissima'],
#    ['@k1ll3r4lov3',
#     'È abbastanza curioso sentir dire da uno del CICAP &quot;Non fermarti a guardare la superficie, prova ad andare a fondo&quot; quando sono loro i primi che banalizzano e non vanno a fondo nelle cose che vorrebbero smentire.'],
#    ['@giub8892',
#     'Sarebbe incredibile una vostra discussione con Corrado Malanga, ne uscirebbero risate e argomenti profondi. Se il CICAP rappresenta la seconda campana, Malanga sarebbe la terza.'],
#    ['@AlessioFichera-mb5tb', 'Giorno 2 chiedendo di invitare Space Valley'],
#    ['@andrevai8427', 'Grande puntata'],
#    ['@antonellostrippoli6926',
#     'Tanto di cappello . Ma riguardo al caso del ciabattino analfabeta o della povera signora che in sogno, hanno profetato i numeri del lotto come si esprime il CICAP? Se è valida la spiegazione che ogni tanto si azzecca concorderete che è una bella serie di variabili che si uniscono.'],
#    ['@alexdisn9280', 'L&#39;intervista più interessante di MS'],
#    ['@TheGianx183',
#     'il cicap parla solo di cagate, ma ognuno con le sue idee'],
#    ['@marcogiovanazzi9278',
#     'memento Paolo Fox in MMXX dicitur &quot;il 2020 sarà un anno favorevole ai viaggi&quot;'],
#    ['@appxappstoresese9561',
#     '<a href="https://www.youtube.com/watch?v=DzLjwWZjr5w&amp;t=2900">48:20</a> urlo di piacere'],
#    ['@maurobosi85', 'Cecchi Paone…'],
#    ['@Dardinello',
#     'Mi ricordo quando nella trasmissione Misteri blastó il medium Umberto Di Grazia!'],
#    ['@marcoruggiero7974',
#     'c&#39;è un oscurantismo digitale che sta riportando la pseudoscienza su scranni legittimi.'],
#    ['@bmgjkgk', 'invitate il papa viene.'],
#    ['@andreagerardi329',
#     'Puntate così erano mesi che non si vedevano… complimenti ragazzi'],
#    ['@ghine7707',
#     'Una delle migliori puntate in assoluto, finalmente quakcuno che porta il cicap'],
#    ['@Dardinello',
#     'Lorenzo Montali lo ricordo nelle puntate di misteri raidue primi anni 90....'],
#    ['@ghine7707', 'Avrei chiamato insieme a lui anche massimo polidoro'],
#    ['@Sig.Silver',
#     'confermo, i miei calzini di maradona mi hanno portato bene solo  le prime due volte...'],
#    ['@gabrieledisotto2962', 'Rega ma questo è il mio prof'],
#    ['@lucaolivieri9218',
#     'Comunque oh, sarebbe bello vedere una chiacchierata tra Martin e Marra'],
#    ['@ilfantino', 'San Gennaro Heinz'],
#    ['@potzzmanjunior1785',
#     'Ammiro tantissimo queste scelte degli ospiti delle puntate di Luis e Martin.<br>Coinvolgenti e deliziosamente interessanti'],
#    ['@zuburag', 'Puntata stupenda.'],
#    ['@user-km2zp5vp7k',
#     'Ragazzi...dedicatevi a cose più leggere...non fate bella figura'],
#    ['@seghementali', 'Ora invitate Corrado Malanga'],
#    ['@user-km2zp5vp7k', 'Principio di INDETERMINATEZZA.....ho spento...'],
#    ['@mattiamango7437', 'ti amo fedez'],
#    ['@user-km2zp5vp7k', 'Cavolo luis fa proprio fatica ad esprimersi'],
#    ['@briele80', 'Fortuna loro che CICAPiscono....... Era meglio Fedez'],
#    ['@fabiusabbile4780', 'Bravissimi top!<br>Altro che Fedez!!!'],
#    ['@gambamozzavendra9354',
#     'Finalmente posso guardarmi il muschio con piacere..siete mancati tanto ragazzi 🙏🏽🫂'],
#    ['@edoardobenanchietti7356', 'Il mio prof di Psicologia Sociale ❤️❤️'],
#    ['@underdestroy',
#     'Rivogliamo Fedez. <br>Il cicap senza contraddittorio è cosa ridicola. Habemus Cicap'],
#    ['@ombradeiricordi', 'Tutto giusto tranne il pregiudizio sui francesi 😂'],
#    ['@TheMiki1704',
#     'Solo a me non trasmettono nulla oltre al cringe? Soprattutto quel Martin sembra il classico finto intellettuale che beve tennents dal Minimarket'],
#    ['@Davevan92', 'Puntata bellissima'],
#    ['@serenafinazzi5764', 'Puntata super'],
#    ['@guidoalberto5019', 'Sembra cattelan'],
#    ['@veramente92',
#     'Ma quindi volete dirmi che all&#39;apice della piramide massonica c&#39;è Martin?'],
#    ['@user-km2zp5vp7k', 'Discorsi molto limitati'],
#    ['@francoalba4871',
#     'Potevate cambiare in:<br>C omitato<br>I taliano<br>C he<br>A rguisce<br>P ropaganda'],
#    ['@celesterusso8240', 'He figa sta puntata la meglio di sempre'],
#    ['@sergiomarinelli4762', 'Final Fight Montali vs Red Ronnie'],
#    ['@sergiomarinelli4762', 'Cazzooo chiamate Red Ronnie'],
#    ['@iacob8465', 'Miglior puntata'],
#    ['@joeler1182',
#     'Il fraintendimento mi pare stia nel passare da un estremo a un altro. Dall&#39;essere irrazionali e superstiziosi al spingere la razionalità al polo estremo in cui si nega qualunque cosa che non sia misurabile dalla scienza presente. Una persona che ha qualche facoltà considerata paranormale potrebbe non essere interessata a ricevere un milione di euro tanto meno essere interessata alla visibilità, fama o gloria personale. Potrebbe inoltre non sapere utilizzare a comando qualche facoltà che emerge in situazioni particolari, come un&#39;emergenza o un&#39;incidente.'],
#    ['@offarwolf5886',
#     'Ho ascoltato con piacere questa intervista, soprattutto per capire qual&#39;è il pensiero del cicap e qual&#39;è l&#39;approccio utilizzato per spiegare o smascherare diversi fenomeni. Ci sono delle cose che vorrei esporre, per potermi interfacciare ed arrivare ad un risultato che esprima coerenza, verità pratica ed intellettuale soddisfacente. Sono pienamente d&#39;accordo che ai giorni nostri, le persone vivono situazioni disperate e purtroppo si affidano a personaggi, che esercitano pratiche al solo scopo di estorcere denaro e non sono per nulla interessati al benessere della persona. Alcuni altri, dopo pochi giorni di corso o dopo dei video registrati, si improvvisano operatori olistici, mental coach od altro, con il risultato di azioni che mettono in ridicolo alcune filosofie, dottrine e pratiche degne di rispetto. <br>Ci sono delle cose e delle persone che invece danno un sincero aiuto alle persone che lo cercano e parlo perché ho verificato individualmente in diversi ambiti dell&#39;esoterismo e altro, anche con occhio da prestidigitatore. <br>In alcuni casi non mi è sembrato di aver visto molto quell&#39;approccio &quot;scientifico&quot;, in alcuni casi ho notato incompletezza e superficialità. Forse sono l&#39;unico che ha interpretato in modo errato questa cosa o forse è da rivedere il messaggio comunicativo che presentate in diversi contesti. Sono tremendamente serio sulla questione e tengo molto a ragionare assieme a voi. <br>- Avete parlato della Pranoterapia e di ciò che ha mostrato questo pranoterapista, che &quot;mummificava&quot; le uova. Non avete per nulla spiegato cos&#39;è la Pranoterapia e a cosa serve realmente. <br>Non posso sapere quanto veramente siete andati in profondità su alcuni argomenti, verificando i diversi fenomeni e persone, posso solo affidarmi alla vostra sincerità. Dalle ricerche fatte e osservate personalmente, (non su Google) è emerso che alcuni Pranoterapisti lavorano negli ospedali per girare i bambini prima della nascita, evitando che le madri facciano il taglio cesario, le verruche ed il fuoco di Sant&#39;Antonio guariscono senza applicare creme, assumere farmaci e diverse altre cose. Sono stato testimone di una persona guarita dal Reiki, presentandomi personalmente tutta la documentazione di interventi, per la rimozione di polipi nasali che gli ospedali non sono stati in grado di risolvere. <br>- Avete parlato di sedute spiritiche e mi chiedo - con sincerità è stata provata una seduta spiritica, con tavola ouija tra di voi del cicap per verificarne il fenomeno? Ma non dico di provare solo una volta ma magari diverse volte, con il giusto intento di contattare quel qualcosa per ricercare quel fenomeno. (Anche se questa cosa la sconsiglio a tutti).<br>- Avete accennato il vostro dissenso verso i Guru, anche se non avete detto il nome di Sathya Sai Baba, il dito era forse soprattutto rivolto a lui parlado di &quot;Guru vestiti di arancio&quot;. Mi chiedo se qualcuno di voi sia andato in India per verificare da vicino e non per sentito dire, perché altrimenti parliamo di una grande incoerenza da parte vostra, che affermate di andare a fondo sull&#39;argomento.<br>Aggiungo che non viene mai spiegato anche nel vostro sito che il Guru è una persona diversa da un maestro spirituale (ovvero chi chiede denaro come Sadguru e altri compagni di merende) e lo spiega anche Baba ammesso che qualcuno abbia ascoltato i suoi discorsi. Dalle testimonianze, discorsi di scienziati, devoti e chi è contrario, testi scritti ed altro materiale, ho raccolto diverse informazioni che portano alla Luce, un&#39;organizzazione degna di profondo rispetto, volta al servizio verso il prossimo con la costruzione di un ospedale, istruzione, distribuzione costante di cibo ai poveri, acqua potabile, condivisione di messaggi importanti per valorizzare le Virtù e Qualità Umane e molto altro. Tutto gratuitamente, con volontari  che lavorano per il sostegno di questa organizzazione e per l&#39;ideale altruistico, tra cu ...
#    ['@ThomasBorgogno', 'Quando portate la Chiesa Pastafariana Italiana? 😍❤️'],
#    ['@lucabelli3253', 'Benone'],
#    ['@GabrieleReverberi-so3sr',
#     'Si ma senza fedez non è muschio, cambiate nome'],
#    ['@ferniemme9605',
#     'I sogni premonitori esistono e io ne ho fatti 3,legge di attrazione sperimentata ed è successo ciò che ho chiesto'],
#    ['@marianna4196', 'intervistate francesco bianconiii'],
#    ['@francypetra',
#     'Il cicap è utile,ma manco San. Tommaso!!!!!Non credono nemmeno se vedono...'],
#    ['@zBlazexZ', 'Cicap iscono un cazzo secondo me'],
#    ['@valentinomanni7105', 'Chiamate Omegaclick e svoltate...'],
#    ['@mtgtradingpost7374',
#     'MAI SENTITA TANTA DISINFORMAZIONE PROPAGANDISTICA E CON 0 RIFERIMENTI SCIENTIFICI. DIFATTI IL PERSONAGGIO è UNO PSICOLOGO E NON UNO SCIENZIATO. continuate a cercare di mischiare la merda con la cioccolata.<br>PS: dite la verità, vi cagate sotto a invitare Malanga he?? (sputtanerebbe il CICAP per intero, siccome era a suo tempo il vicepresidente del CICAP)'],
#    ['@user-ud4qg2ds4f',
#     'Come mi spiegate perché alcune persone hanno sempre fortuna nonostante siano delle merde umane?'],
#    ['@shetalkstorainbows3', 'ma quindi lui è tipo peter venkman ?'],
#    ['@Dibla0',
#     'Luis ma ancora stai qui ? Ma che ospiti porti ?? Si salvano alcuni ma ti mancano idee sul che domandare, ti manca chi mandava i pezzi grossi dell’entertainment?….nulla da togliere all’ospite in puntata ho solo premesso che ha rovinato un podcast dove portava risate e approfondimento allo stesso tempo , dove infine luis porta gente come sdrumox, la hunziker….è diventato il bar di quartiere dei anni 90 che nessuno frequenta'],
#    ['@Tantope',
#     'Finalmente una puntata interessante, senza influencer che parlano del nulla :)'],
#    ['@giuseppeiannello4681', 'Cibo per la mente'],
#    ['@fabioguarigno6931',
#     'Prestigiatore della dialettica come tutti i cicappini.'],
#    ['@samuelabonafe5217',
#     'Invitate anche il prof. Malanga meglio di quel super massone di Piero Angela suo mentore'],
#    ['@samuelabonafe5217',
#     'Dimostrare un fenomeno paranormale è una contraddizione in termini in quanto un fenomeno paranormale non può essere dimostrato x definizione non è replicabile!'],
#    ['@gianlucadreoni1142',
#     'La 2° puntata è passata da un po&#39; , eppure va avanti anche senza il piangina 😂'],
#    ['@VaseaM13', 'Molto interessante'],
#    ['@noom.0_0',
#     'sono al minuto <a href="https://www.youtube.com/watch?v=DzLjwWZjr5w&amp;t=3766">1:02:46</a>.3 e continuo a chiedermi, ma perché lo stato italiano non riscuote i debiti che lo stato vaticano ha con esso? magari reinvestendoli nel cicap per sfatare le più grandi fondamenta della chiesa, tipo datare reperti storici e\\o si poteva prendere per esempio Adamo ed Eva e il rafforzamento che ha avuto la chiesa nel dire &quot;no ma che centra perché quella è una parte che va interpretata mentre le altre sono vere..&quot;😂'],
#    ['@23frankie_rose17',
#     'Dovreste invitare anche Dario Bressanini, sarebbe bellissimo!'],
#    ['@DevisCherubini', 'Bellissima puntata!'],
#    ['@mark1s385', '(quegli sfigati del CICAP)'],
#    ['@quickus01', 'Prossimo ospite franchino er criminale?'],
#    ['@filippo2244',
#     'Non c’era Fedez… se no si che gli andava contro al cicap'],
#    ['@thea5331',
#     'Wow che bella puntata, super interessante 🥰. Professore davvero molto bravo, non conoscevo l&#39;associazione. Purtroppo sono lontano da Padova, ma mi segno comunque le date🥰. Saranno registrati o visibili anche da remoto alcuni incontri?'],
#    ['@mattiabassi2744',
#     'Sebbene sia un grande fan di Marra e Fedez, ed abbia visto indipendentemente tutte le puntate di Muschio, reputo questo episodio uno dei più belli ed interessanti'],
#    ['@CokoZ',
#     'Mi sono fermato nell ascoltare questo professore già da quando ha detto che sulla luna gli americani ci sono andati, per lui tutto è suggestione, illusione scaramanzia e manipolazione , ma non può essere manipolazione anche l&#39; allunagio?'],
#    ['@scot87contediripafratta98',
#     'Una puntata ricca di suspense e colpi si scena al pari del rosario delle 17 alla cappella di San Adalgise in polverosa in provincia di Ferrara.'],
#    ['@ro_cuore1979nagual',
#     'Salve sulls luna non ci siamo mai andati perche se pasiamo un certo limite della atmosfera che circonda la terra tutto esplode oppure succede che le lersone muoiono è i materiali brucciono'],
#    ['@mirkodifederico3479', 'Le visualizzazioni stanno volando 😂😂😂😂😂😂'],
#    ['@DanaXScully',
#     'Grandissima puntata. Luis mi ha perso 100 punti simpatia perché non conosce X-Files, ma complimenti, l&#39;episodio più interessante di tutti. Attendo con ansia anche Massimo Polidoro.'],
#    ['@solidsnake1616',
#     'Non è tutto spiegabile molti fenomeni rimangono un mistero…. Pier fortunato Zanfretta, Gustavo Rol, lo stesso sbarco sulla Luna una delle balle più grandi della storia ecc…'],
#    ['@infobizacademy2023', 'In Italia avevamo Adolfo gustavo rol'],
#    ['@psicologiasenzapoesia',
#     'Le credenze religiose si sono affermate perchè nella storia etologica evolutiva degli esseri umani hanno favorito la sopravvivenza degli individui che appunto condividevano le stesse fedi. Credere nelle stesse cose permette alle persone di formare gruppi sempre più ampi e coesi e pertanto maggiormente protettivi. Chi non credeva veniva isolato e quindi rischiava maggiormente di morire senza fare figli. Chi credeva faceva figli e trasmetteva il gene della fede.'],
#    ['@laracroff4184',
#     'Puntata bellissima, si vede che l&#39; ospite è un professore, mi ha tenuta incollata per 1&#39;20 h , fantastico ❤ grazie'],
#    ['@editingreallifenow', 'Bellissima puntata ora la guardo'],
#    ['@giosa7422', 'Bella puntata'],
#    ['@raff4el3', 'TOP'],
#    ['@solidsnake1616', 'Sul vaccino covid il cicap dovrebbe tacere!'],
#    ['@riccardo566',
#     'Complimenti ragazzi siete partiti alla grande, e senza fedez siete molto più in sintonia tra di voi'],
#    ['@ema-eo9yu', 'R.I.P. Piero Angela'],
#    ['@nataschiapisano109', 'Finalmente!'],
#    ['@karlitos2', 'Finalmente si lascia parlare la persona ospitata'],
#    ['@dottorT27', 'Soccia, che puntata! 🤩'],
#    ['@gioeletirello2423',
#     'Ma perché avete fatto doppiare l&#39;ospite a Martin?'],
#    ['@annanarde', 'A quando Alessandro Barbero?'],
#    ['@Anticountryclub____', 'Si ok ma Bologna?'],
#    ['@annanarde', 'Bellissima puntata e splendido lavoro quelli del CICAP.'],
#    ['@enricomarchesini1868', 'Più CICAP meno Biglino'],
#    ['@ant1onedj', 'il nuovo muschio selvaggio da vomito'],
#    ['@ebrahimelsherif1461', '⚠️ Nuovo ospite fedez!'],
#    ['@francescahs8866',
#     '&quot;I want to believe&quot; non è di ufology, ma è stato ideato da Chris Carter il creatore di X-Files, la serie famosissima americana sui fenomeni paranormali. Era il poster che aveva Mulder nel suo ufficio. Poi utilizzato impropriamente dai complottisti, ma in realtà la serie non lascia spazio a nulla se non alla scienza di svelare tutti i trucchi.'],
#    ['@junkfoods',
#     'un docente universitario che usa il &quot;piuttosto che&quot; in maniera errata  <a href="https://www.youtube.com/watch?v=DzLjwWZjr5w&amp;t=163">2:43</a>'],
#    ['@andreacervioni8434', 'Bellissima puntata, grazie mille al professore'],
#    ['@Franci448', 'Bellissima puntata!'],
#    ['@alessiafara9091', '🐑🐑🐑🐑🐑🐑🐑🐑'],
#    ['@tbas_official', 'Ah perché siamo stati sulla Luna? Che pena'],
#    ['@antoniovitiello9837',
#     'Quello che mi chiedo io e che se i film di the conjurig fossero davvero tratti da storie vere come si spiegherebbero quei eventi'],
#    ['@carmenguarino8587',
#     'Bellissimo intervento. Onorato di averlo conosciuto dal vivo. Grazie CICAP'],
#    ['@emanuelepinto3432',
#     'Sarebbe bello avere un video dell evento citato alla fine (spero di dare l idea)'],
#    ['@francescodibiase59',
#     'il fatto è che molto probabilmente, alcune cose non possono essere dimostrate.'],
#    ['@perigungia',
#     'Che piacere ritrovare il prof montali ospite ad uno dei podcast che ascolto più volentieri. È sempre interessante ascoltarlo'],
#    ['@RC-dj3us',
#     'tutta  l&#39;operazione  di  LUIS  SAL  e&#39;  finalizzata  a  ripiazzare  il  fratello...i  risultati  pero&#39;  scarseggiano  ...muschio  morente  altro  che  selvaggio'],
#    ['@CastaSocialeGiovy', 'Così simpatico fuori dagli esami'],
#    ['@Lagaialove', '💣'],
#    ['@danielesaracino662', 'Ragazzi fate stare l’ospite al centro del tavolo'],
#    ['@brunovollaro2559',
#     'Invitatemi in qualità di Alchimista e vi smentisco il professore punto per punto. La logica ha delle falle enormi, il cervello che è un calcolatore non può capire qualsiasi cosa ed è facilmente dimostrabile! 😌🙏❤️✨️'],
#    ['@user-co8dz7vr7e', 'Meglio marra  speriamo che torni'],
#    ['@marcomotta2507', 'FED a muschio selvaggio prima di gta VI'],
#    ['@slfsquad5877',
#     '<a href="https://www.youtube.com/watch?v=1ov4W496tyU">https://youtu.be/1ov4W496tyU?si=1_MgeLsIExHY3qCJ</a>'],
#    ['@stefanozago9284',
#     'No vabbe Martin si è perso Don Diego de la Vega col capello lungo'],
#    ['@federicabertolucci2967',
#     'Grazie ragazzi per avere scelto questo ospite perché ho potuto imparare qualcosa di interessante!! E continuate così perché la qualità delle informazioni che a noi arriva é nelle vostre mani ora!'],
#    ['@ludovicobotto3706', 'la tv è storta o sbaglio? aha'],
#    ['@Druk88', 'Bella puntata complimenti, viva il cicap!'],
#    ['@JustaNamebutverycool',
#     'Che guevara sotto copertura per combattere i fascisti'],
#    ['@3200sam',
# ...
#    ['',
#     'è sconsigliato andare in alcuni posti specifici dell&#39;Aspromonte, ma tutto il resto è bellissimo, cercate &quot;Petra Cappa&quot; è il monolite più grande d&#39;Europa e si trova in Aspromonte, tanto per dirne una ^_^'],
#    ['@gabrielef97',
#     'Solidarietá per Shy! Assenza di ospitalitá e coinvolgimento vergognosa!'],
#    ['@AGiovi', 'Shy sei un grande. Fedez pessimo e insopportabile.'],
#    ['@federico1601', 'disagio'],
#    ['@cicciobaciccio2564',
#     'Shy : un grande (come al solito) ... gli altri tre... dire &quot;spenti&quot; e&#39; fare un complimento... un sonno pazzesco'],
#    ['@francmar10', 'Insomma il podcast lo ha tenuto shy sto giro'],
#    ['@Warmalin',
#     'È la prima volta che vedo questo podcast per intero, noto che l&#39;audio è tutto sfasato tra un partecipante e l&#39;altro, le riprese in primo piano fanno venire mal di testa e sono inutili.'],
#    ['@bellafrade', 'grande shy'],
#    ['@andreagilberti2233',
#     'Cercando i primi video i primi 30 sono soggetti a limiti di età...'],
#    ['@susannadescalzo5250', 'A me è piaciuta sta puntata'],
#    ['@sussurroabissale8565',
#     'Il Kuniyoshi sulla maglietta mi distrae, troppo bello'],
#    ['@solarselvix4583',
#     'La cosa che trovo più fastidiosa di questa intervista, al di fuori della mancanza della benché minima domanda interessante, è il modo con cui si rivolgono nei confronti dell’ospite. Quasi al limite del nullafreghismo e sparando frasi rivolte alla Sardegna come se fosse un’isola sperduta nel mondo, popolata da esseri non definiti. Avreste potuto chiedergli 1000 domande, non ne avete azzeccata una, incredibile'],
#    ['@AlbyTheMovieCreator',
#     'Solo io trovo svapare in un podcast estremamente insensibile e irrispettoso? Cazzo per un ora smerdosa non puoi evitare di sbuffare il fumo in faccia agli ospiti costringendoli a respirare la tua roba? Condiserando anche i tempi che corriamo non è il massimo del massimo.'],
#    ['@mvnfre_music',
#     'Palese che Fedez voglia essere l&#39;unico vero ospite sempre e da buon cavalcatore della società cerca di tirare fuori sempre citazioni sulle spalle degli altri. Peccato perché bisognerebbe cercare di imparare dagli altri e non sminuirli'],
#    ['@diegodeiud8322',
#     'Quello che ho imparato in questa puntata è che i Sardi hanno palesemente il patrimonio genetico degli Elohim'],
#    ['@illeoyt2070',
#     'CRITICA COSTRUTTIVA:<br>regolate per favore i volumi dei microfoni, ogni persona ha un volume di voce differente, tipo in questo caso l&#39;ospite parla piuttosto alto mentre Martin molto piano per ascoltare uno devi alzare il volume mentre per l&#39;altro abbassare parecchio, si diventa scemi'],
#    ['@yanavjiqoike6686', 'che puntata piatta'],
#    ['@tanet',
#     'ma scrivete tutti gli stessi commenti? che cazzo siete degli androidi?'],
#    ['@26Marila',
#     'Ma che vi è successo?! Litigone in redazione (o quello che è)?!'],
#    ['@cicciodinonnapapera7798',
#     'Bell&#39;episodio<br> C&#39;è anche la versione in cui Martin ha il microfono acceso?'],
#    ['@_gabrielemontagni', 'Tutto molto bello ma Martin alza la voce 😁'],
#    ['@simonec3245', 'Tristezza infinita'],
#    ['@christianneri5288',
#     'Bello tutto, anni de video su YouTube, anni de dischi, c&#39; avete i fantamilioni, come cazzo è possibile che un microfono non se senta? Dai oh'],
#    ['@Effedoppio',
#     'Trovo disgustoso il fatto che, nonostante questo podcast stia ormai toccando terribili momenti di bassezza, la gente continui a guardarlo e loro - Fedez, Luis, etc. - non facciano nulla per migliorarsi. È come assistere alla potenza irremovibile di un colosso che opera in regime di monopolio assoluto. Purtroppo i grandi Ferrario e Ravenna di Cachemire non sono tanto popolari da ottenere tutta l’attenzione che riesce subito a riscuotere Muschio Selvaggio grazie a Fedez e Luis. Il risultato è che, nel bene e nel male, si finisce tutti per guardarsi le puntate di questa schifezza, che si mantiene a galla senza alcun merito. Io stesso mi ritrovo a guardarne le puntate perché salgono puntualmente tra le tendenze innescando in me una curiosità della quale ogni volta mi pento...'],
#    ['@alessandroveerappen9583',
#     'Martin facci sto regalo! E usa sto microfono'],
#    ['@tgianno744', 'Audio Martín . Grazie alla prossima.'],
#    ['@aliibeipilates', 'Male male'],
#    ['@carlocosenza2',
#     'Grande Shy, una persona di una sensibilità rara, capace di arrivare a tutti'],
#    ['@valeriolato',
#     'Incredibile (e a mio avviso triste) come questo video abbia così poche views rispetto ai precedenti.'],
#    ['@DNATNA97',
#     'Primo podcast che vedo però mi sembra che shy si sia divertito, non capisco le troppe critiche'],
#    ['@brenno344', 'Fedez a sto giro mi è piaciuto particolarmente.'],
#    ['@madontchoke',
#     'state attenti ai volumi dei microfoni dio bono, martin parla dall&#39;oltretomba'],
#    ['@Nightmare-te8cc',
#     'Podcast di merda con conversazioni ridicole come sempre'],
#    ['@andrealfo', 'martin avvicina la bocca al microfono pls'],
#    ['@libano3812',
#     'Uno che non sa pronunciare maneskin e parla delle notizie del giorno.. Ma dai.. Pd.. Il solito sardo che cerca di inventarsi.. D&#39;essere il nuovo Carta'],
#    ['@libano3812',
#     'Che poi uno pensa, meglio parlare per 57 minuti e non dire un cazzo o meglio stare zitti per 57 min e non dire un cazzo...'],
#    ['@libano3812',
#     'Cge paraculo sto tipo.. Pubblica notizie ma non si espone mai.. Dicendo di non dover x forza farlo..'],
#    ['@MrBlur198',
#     'Fedez mi sa che se l&#39;è presa per tutte quelle battutine che Shy fa sullo svapare :&#39;)'],
#    ['@libano3812',
#     'Vi aspettate entusiasmo da questa puntata ma quello che racconta il &quot;giornalista&quot; son tutte fregnacce.. Sappiamo come il giornalismo italiano abbia solo una fede.. Quella politico-monetaria.. E fedez lo ha capito benissimo.. Quindi perché il giornalaio deve dipingere una cosa per bella e pulita.. Quando non lo è'],
#    ['@lorenzobellardi9936',
#     'Riassunto puntata:<br>Martin ASMR soft spoken and whispering'],
#    ['@wapitodrip9659',
#     'ahah, sinceramente mi fa un po&#39; ridere leggere i commenti, rilassatevi va&#39;'],
#    ['@Contrawler99', 'Fedez giullare del sistema.'],
#    ['@gianmarcovisentin6248',
#     'Vi prego, i volumi dei microfoni.<br>Ascoltando dalla macchina si sente fortissimo shy e niente voi, è inascoltabile<br>Avete un microfono a testa, non è difficile fare post produzione e mettere il giusto gain a tutti'],
#    ['@pionieresvizzero2224',
#     'RIDATEMI INDIETRO QUESTI 57 MINUTI PERSI DELLA MIA VITA'],
#    ['@mayronnadalin4305',
#     'Mi fa ridere che è la prima volta che la gente si rende conto di quanto è greve fedez, non segui così tanto shy ma godo che grazie a lui la gente ha iniziato ad aprire gli occhi. Fedez podi podi'],
#    ['@vapertv713',
#     'Mai possibile che non equalizzate l&#39;audio? (Si dice così?) Martin troppo basso, l&#39;ospite troppo altro cioè io che seguo il podcast in auto da Spotify sto ogni secondo a regolare l&#39;audio, poi mi rassegno e immagino quello che dice Martin.'],
#    ['@alessandrogrillone1173',
#     'Prima di aprire il video le mie aspettative erano alte. Iniziato il video mi rendo subito conto che non era come me lo aspettavo. Dopo 10 minuti ho deciso di continuare a guardarlo solo per vedere quanto l&#39;intervista fosse fatta male e quanto imbarazzante fosse. Le domande non sembrano neanche rivolte a Shy, ma ad un estraneo qualunque, con il quale non si sa cosa raccontarsi. Imbarazzo costante. Domande tirate fuori a fatica. Intervista da buttare, occasione sprecata. Mi dispiace per Shy'],
#    ['@Manu_79',
#     'Raga ma siete seri? Adoro muschio selvaggio ma avere SHY, che di solito non esce mai dalla Sardegna, e riuscire a parlare di un cazzo? E oggi ve ne uscite con capo plaza che non ha nulla da dire nei suoi pezzi figurati nella vita reale. Ma andate a fanculo'],
#    ['@emanuelemurru8593',
#     'Il video sta avendo poche visualizzazioni in confronto agli altri. Praticamente solo noi che seguiamo Shy. Ecco perché quell&#39; opportunista che si finge campione di grandi battaglie che è Fedez (battaglie che in realtà fa solo per fini personali, è evidente che vuole diventare primo ministro un giorno e quindi sia fissato col potere - infatti critica il potere degli altri perché lui vuole crearsi uno spazio per il SUO di potere), era disinteressato all&#39; ospite che aveva davanti. Purtroppo la comunità di Shy (come dice anche lui stesso) è una bolla che non riesce a diventare popolare , non certo per demeriti di Shy, anzi forse perché lui è un signore e devi essere faccia da cazzo e marito di una come la Ferragli per essere popolare. Inoltre da sardo constato che in continente il nostro accento dia fastidio non per male ma perché sardi influenti e famosi se ne contano nelle dita della mano e quindi voi continentali, non essendo abituati,  tendete ad evitare di sentire un sardo che parla perché vi fa strano. Questo è un altro motivo per cui quella di Shy rimane una bolla fatta di sardi, continentali molto aperti a cui non da fastidio l&#39; accento sardo e soprattutto di utenti giovani interessati alla verità (quella che segue scrupolosamente Shy) e non per forza a vedere il mondo come fatto di amici e nemici, o solo nero o solo bianco come fanno Fedez e molti sinistri da una parte e i fascio-leghisti -meloniani-sovranisti dall&#39; altra.'],
#    ['@lucaa0201', 'Fedez una vergogna...'],
#    ['@Jod4light',
#     'La peggior puntata di muschio! Se non avete voglia di far il podcast cambiate giornata/orario/attività!<br>Avevate un ospite eccezionale ma voi non eravate nemmeno interessati ad ascoltarlo.'],
#    ['@FabioCatalano',
#     'Noioso. Peccato, Shy era un grande ospite per approfondire tutto quello che è BreakingItaly'],
#    ['@theDivine01',
#     'Dopo questa puntata ho capito che il vostro range è Donatella Versace...... imbarazzante il vostro comportamento e non sono un fanboy di shy'],
#    ['@gabrielefalletta5176', 'siete arrivati a 777.000 iscritti'],
#    ['@sgw8707', 'Idk alessandro the guardian is kind of trash'],
#    ['@sofiapanconi3914',
#     'Ma rega se vi pesa riempire il silenzio forse un dovevate aprire un podcast...lol'],
#    ['@sofiapanconi3914', 'Non si sente Martin'],
#    ['@emanuelegennuso1901', 'QUANDO DARIO GREGGIO IN SALA?'],
#    ['@TheZanix',
#     'Non ho mai guardato muschio selvaggio, ma ho voluto fare un tentativo solo perché c&#39;è Shy.<br>Terribile, nessuno di loro è preparato (non ho nulla contro l&#39;improvvisazione, ma sembrava di avere una classe di 2a elementare a fare delle domande campate in aria). Gli audio sono ridicoli, Martin praticamente muto e Shy invece troppo alto.<br>Ma rimane un podcast di successo visti i numeri, quindi forse sono sbagliato io? Bah....'],
#    ['@lucs5106',
#     'Ma Martin è capace di parlare al microfono? Nn si sente un c....'],
#    ['@travisscotti', 'SI VEDONO I COMMENTI DEL PUCCLICO DI SHY XD'],
#    ['@Ilbarbaxjr',
#     'Ragazzi, ve lo dico senza voler denigrare il vostro podcast e ci mancherebbe, la mia vuole essere una critica costruttiva. Dovete assolutamente fare qualcosa per risolvere il problema dell&#39;audio che è a dir poco scadente, anche a livello hobbistico sarebbe inaccettabile (ho veramente sudato per riuscire a sentire le domande rivolte a Masala, il cui microfono fra l&#39;altro era quello che si sentiva meglio) , poi magari valuterei seriamente l&#39;idea di fare una scaletta più &quot;pensata&quot; e un pò  più &quot;cucita&quot; addosso a chi caspita intervistate, sennò le domande rischiano di essere veramente piatte e banali per non dire sterili. Buon lavoro.'],
#    ['@lucaraneri8843', 'Invitate Frank Gramuglia'],
#    ['@aleevadh', '&quot;ma condurre breaking italy fa scopare di più? &quot;'],
#    ['@MarkAsky147',
#     'Innanzitutto possiamo &quot;permetterci&quot; di criticare questa puntata o alcuni aspetti di Muschio Selvaggio per il semplice motivo che Muschio Selvaggio &quot;c&#39;è&quot;.. e non è poco. Quindi premesso che si puo sempre migliorare/cambiare, prima di tutto un bel grazie ci sta, per questa puntata e per tutte le altre. Poi pure io ho vissuto con molte aspettative questo episodio che in qualche modo sono state deluse per i vari motivi già elencati nei tanti post precedenti. Sono tutte persone itelligenti e quindi sono sicuro che le critiche costruttive verranno ascoltate e saranno propedeutiche per un miglioramento del podcast. Quindi grazie ancora per il gradevole intrattenimento offerto gratuitamente e se avremo la fortuna di vedere un&#39;altra puntata con Shy magari insieme a qualche altro ospite sicuramente non ci lamenteremo :)'],
#    ['@fabriziomorenzetti8775',
#     'Solitamente ascolto il podcast, se si sentisse l&#39;audio di Martin e di Luis sarebbe utile, però anche così è uno show super 😓'],
#    ['@mariofarina7600',
#     'La proposta del canale da tuttologo puntualmente respinta da Alessandro fa capire quanto fedez sia una creatura da social che vive del dibatto flash superficiale e che si sente pure di aver fatto qualcosa di utile sparando due qualunquate'],
#    ['@riccardocastagna4991',
#     'Ma sbaglio o shy ha chiesto palesemente “AIUTO”?'],
#    ['@Max_is_Max', 'LUIS FEDEZ martin:)'],
#    ['@gabrielebistoletti3160', 'Avete parlato un ora senza dire niente'],
#    ['@francescotedesco8671', 'puntata con i maneskin?'],
#    ['@giuliopasini4757',
#     'Il tipo con la t-shirt con lo scheletro...<br>O gli alzate il volume del mic o gli dite di tirar fuori un po&#39; di voce, cazzo...<br>XD<br><br>Grande Shy :)))'],
#    ['@davide1244', 'Ma chi è questo'],
#    ['@napoleonebonaparte1952', 'Mamma mia che palle'],
#    ['@enzognesutta3201',
#     'Fedez con le persone intelligenti si sente a disagio'],
#    ['@angelo8430',
#     'Condivido molti pareri tra i commenti e non ripeto ma la cosa più grave è la mancanza assoluta di rispetto di Fedez. Chapeau a Shy per aver gestito con eleganza la situazione.'],
#    ['@cipciop2305', '@yotobi'],
#    ['@omegaburst1121',
#     'Ospite enorme. Muschio minuscolo. Peccato non averlo sfruttato a pieno, meglio parlare di tizie che bevono sborra. Ok.'],
#    ['@massimoleoni2326',
#     'Qualcuno può mettere i sottotitoli a Martin per favore? 😂'],
#    ['@KK-xs5ou',
#     'Fedez fa domande ma non gliene frega un cazzo delle risposte'],
#    ['@KK-xs5ou',
#     'Raga ma che cazzo di intervista è?<br>Fedez sembra me il lunedì mattina alle 6 a lavoro,Luis il solito,non si è mai contraddistinto in questo podcast,Martin boh manco si sente che cazzo dice.<br>Peccato perchè l&#39;ospite era di alto livello'],
#    ['@stellamantani712',
#     'per fare una buona conversazione, non servono per forza paroloni per risultare più intelligente.<br>Meglio semplice che inutilmente complicato'],
#    ['@DarkSideApproach',
#     'Triste che una puntata con questo potenziale sia la più brutta'],
#    ['@raffaelep35', 'Vogliamo omega click'],
#    ['@raffaelep35', 'VogliamoOmega click'],
#    ['@federica4744', 'Non riesco a finire … troppo noioso …'],
#    ['@deamnan3736', 'Che CRINGE Luis🤦🏻'],
#    ['@nicodeca80',
#     'Uno dei personaggi più interessati e con più argomenti semplicemente abbandonato a se stesso. Mi sono sempre piaciute le atmosfere di Muschio però qui toppano di brutto. Forse non avere agganci per citare “Bologna” o “LA” o “Justin Beaber” li avrà confusi ma l’atteggiamento verso l’ospite è stato veramente penoso. Ancora più penoso l’umorismo di Luis verso la Sardegna, ignorante e ridondante. Credo che diano il meglio quando non devono affrontare contenuti e ospiti con una testa più pensante della loro. Nel cazzeggio e nella goliardia ci stanno e fanno anche compagnia, dovrebbero continuare su quella strada.'],
#    ['@aleben6009', 'Fedez ha litigato con qualcuno. Si vede.']],
#   'details': {'title': 'Ep.57 Fixing Italy con Alessandro Masala - Muschio Selvaggio Podcast',
#    'published_at': '2021-05-31 14:14:55',
#    'likes': 31360,
#    'views': 670671,
#    'comment_count': 2086}}}

# %% [markdown]
# ## Costruzione della rete

# %% [markdown]
# La procedura per la costruzione della rete è la seguente:
#
# **Per ogni** coppia $(w,v)$ di video ottenibile dalla collezione dei video:<br>
# &ensp;&thinsp;Calcolare il numero di commentantori in comune tra $w$ e $v$<br>
# &ensp;&thinsp;Inserire nella rete un arco tra $w$ e $v$ il cui peso è il numero di co-commentatori
#
# Dato un insieme/sequenza di elementi in Python possiamo agilmente farci restituire tutte le possibili coppie che posso comporre con gli elementi della sequenza utilizzando la funzione `combinations` del modulo `itertools`.
#
# Importiamo quindi la funzione, la cui documentazione è disponibile [qui](https://docs.python.org/3/library/itertools.html#itertools.combinations).
#
# Generiamo quindi le possibili coppie di video ed implementiamo la precedente procedura. Prima di implementare la procedura si costruisce un grafo vuoto, in questo caso non orientato.

# %%
# grafo vuoto non orientato
muschio_net = nx.Graph()

# %%
# Aggiungi nodi al grafo con gli attributi
for video_id, data in videoToCommenters_with_details.items():
    # Aggiungi i dettagli del video come attributi del nodo
    muschio_net.add_node(video_id, **data['details'])

# Aggiungi archi pesati per la condivisione di commentatori
for video1, video2 in combinations(videoToCommenters_with_details.keys(), 2):
    # Ottieni gli ID dei commentatori per i due video
    commenters1 = set(commenter for commenter, _ in videoToCommenters_with_details[video1]['commenters'])
    commenters2 = set(commenter for commenter, _ in videoToCommenters_with_details[video2]['commenters'])
    # Calcola gli ID dei commentatori in comune
    common_commenters = commenters1.intersection(commenters2)
    # Aggiungi un arco solo se ci sono commentatori in comune
    if common_commenters:
        muschio_net.add_edge(video1, video2)

# %%
# Salva il grafo in formato GEXF con gli attributi
nx.write_gexf(muschio_net, 'muschio_net.gexf')

# %% [markdown]
# prima cosa da fare: generare tutte le combinazioni

# %%
muschio_net.size(), muschio_net.order()
# Out:
# (3112, 100)

# %% [markdown]
# CARICO IL MIO GRAFO

# %%
muschio_net = nx.read_gexf('muschio_net.gexf')

# %% [markdown]
# prendo il file che ho generato e lo apro con Gephi per visualizzare il grafo
