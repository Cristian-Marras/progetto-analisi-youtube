# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://deepnote.com/docs/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here.
# if test -f requirements.txt
#   then
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install."
# fi
# Out:
# Collecting google-api-python-client
#   Downloading google_api_python_client-2.172.0-py3-none-any.whl (13.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.6/13.6 MB 60.4 MB/s eta 0:00:00
# Collecting networkx==3.2.1
#   Downloading networkx-3.2.1-py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 67.5 MB/s eta 0:00:00
# Collecting feel-it
#   Downloading feel_it-1.0.5-py2.py3-none-any.whl (6.1 kB)
# Collecting cdlib==0.4.0
#   Downloading cdlib-0.4.0-py3-none-any.whl (263 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 263.6/263.6 kB 31.1 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /root/venv/lib/python3.9/site-packages (from cdlib==0.4.0->-r ./requirements.txt (line 4)) (2.1.4)
# Collecting bimlpa
#   Downloading bimlpa-0.1.2-py3-none-any.whl (7.0 kB)
# Collecting python-louvain>=0.16
#   Downloading python-louvain-0.16.tar.gz (204 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.6/204.6 kB 30.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting pooch
#   Downloading pooch-1.8.2-py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.6/64.6 kB 10.5 MB/s eta 0:00:00
# Collecting pulp
#   Downloading pulp-3.2.1-py3-none-any.whl (16.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 57.9 MB/s eta 0:00:00
# Requirement already satisfied: seaborn in /root/venv/lib/python3.9/site-packages (from cdlib==0.4.0->-r ./requirements.txt (line 4)) (0.13.2)
# Collecting eva-lcd
#   Downloading eva_lcd-0.1.1-py3-none-any.whl (9.2 kB)
# Requirement already satisfied: tqdm in /root/venv/lib/python3.9/site-packages (from cdlib==0.4.0->-r ./requirements.txt (line 4)) (4.67.1)
# Collecting angelcommunity
#   Downloading angelcommunity-2.0.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: numpy in /root/venv/lib/python3.9/site-packages (from cdlib==0.4.0->-r ./requirements.txt (line 4)) (1.25.2)
# Collecting python-Levenshtein
#   Downloading python_levenshtein-0.27.1-py3-none-any.whl (9.4 kB)
# Collecting thresholdclustering
#   Downloading thresholdclustering-1.1-py3-none-any.whl (5.3 kB)
# Collecting python-igraph>=0.10
#   Downloading python_igraph-0.11.9-py3-none-any.whl (9.2 kB)
# Requirement already satisfied: scikit-learn in /root/venv/lib/python3.9/site-packages (from cdlib==0.4.0->-r ./requirements.txt (line 4)) (1.1.3)
# Collecting scipy>=1.10
#   Downloading scipy-1.13.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.6/38.6 MB 14.9 MB/s eta 0:00:00
# Collecting demon
#   Downloading demon-2.0.6-py3-none-any.whl (7.3 kB)
# Requirement already satisfied: plotly in /root/venv/lib/python3.9/site-packages (from cdlib==0.4.0->-r ./requirements.txt (line 4)) (6.0.1)
# Collecting dynetx
#   Downloading dynetx-0.3.2-py3-none-any.whl (39 kB)
# Collecting google-auth-httplib2<1.0.0,>=0.2.0
#   Downloading google_auth_httplib2-0.2.0-py2.py3-none-any.whl (9.3 kB)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0 in /root/venv/lib/python3.9/site-packages (from google-api-python-client->-r ./requirements.txt (line 1)) (2.40.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in /toolkit-cache/0.2.23/python3.9/kernel-libs/lib/python3.9/site-packages (from google-api-python-client->-r ./requirements.txt (line 1)) (2.19.2)
# Collecting httplib2<1.0.0,>=0.19.0
#   Downloading httplib2-0.22.0-py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.9/96.9 kB 5.5 MB/s eta 0:00:00
# Collecting uritemplate<5,>=3.0.1
#   Downloading uritemplate-4.2.0-py3-none-any.whl (11 kB)
# Requirement already satisfied: torch>=1.6.0 in /root/venv/lib/python3.9/site-packages (from feel-it->-r ./requirements.txt (line 3)) (1.12.1)
# Collecting transformers>=4.11.3
#   Downloading transformers-4.52.4-py3-none-any.whl (10.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.5/10.5 MB 30.9 MB/s eta 0:00:00
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /toolkit-cache/0.2.23/python3.9/kernel-libs/lib/python3.9/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client->-r ./requirements.txt (line 1)) (1.24.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0.dev0,>=3.19.5 in /root/venv/lib/python3.9/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client->-r ./requirements.txt (line 1)) (4.25.7)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /toolkit-cache/0.2.23/python3.9/kernel-libs/lib/python3.9/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client->-r ./requirements.txt (line 1)) (1.65.0)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /root/venv/lib/python3.9/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client->-r ./requirements.txt (line 1)) (2.32.3)
# Requirement already satisfied: rsa<5,>=3.1.4 in /root/venv/lib/python3.9/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client->-r ./requirements.txt (line 1)) (4.9.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /root/venv/lib/python3.9/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client->-r ./requirements.txt (line 1)) (0.4.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /root/venv/lib/python3.9/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client->-r ./requirements.txt (line 1)) (5.5.2)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /root/venv/lib/python3.9/site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client->-r ./requirements.txt (line 1)) (3.2.3)
# Collecting igraph==0.11.9
#   Downloading igraph-0.11.9-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 25.8 MB/s eta 0:00:00
# Collecting texttable>=1.6.2
#   Downloading texttable-1.7.0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: typing-extensions in /root/venv/lib/python3.9/site-packages (from torch>=1.6.0->feel-it->-r ./requirements.txt (line 3)) (4.13.2)
# Collecting tokenizers<0.22,>=0.21
#   Downloading tokenizers-0.21.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 76.3 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /root/venv/lib/python3.9/site-packages (from transformers>=4.11.3->feel-it->-r ./requirements.txt (line 3)) (3.18.0)
# Collecting safetensors>=0.4.3
#   Downloading safetensors-0.5.3-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (471 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 471.6/471.6 kB 43.7 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /root/venv/lib/python3.9/site-packages (from transformers>=4.11.3->feel-it->-r ./requirements.txt (line 3)) (25.0)
# Collecting huggingface-hub<1.0,>=0.30.0
#   Downloading huggingface_hub-0.33.0-py3-none-any.whl (514 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 514.8/514.8 kB 54.3 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml>=5.1 in /root/venv/lib/python3.9/site-packages (from transformers>=4.11.3->feel-it->-r ./requirements.txt (line 3)) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /root/venv/lib/python3.9/site-packages (from transformers>=4.11.3->feel-it->-r ./requirements.txt (line 3)) (2024.11.6)
# Requirement already satisfied: future in /root/venv/lib/python3.9/site-packages (from angelcommunity->cdlib==0.4.0->-r ./requirements.txt (line 4)) (1.0.0)
# Requirement already satisfied: matplotlib in /root/venv/lib/python3.9/site-packages (from bimlpa->cdlib==0.4.0->-r ./requirements.txt (line 4)) (3.6.3)
# Requirement already satisfied: decorator in /root/venv/lib/python3.9/site-packages (from dynetx->cdlib==0.4.0->-r ./requirements.txt (line 4)) (5.2.1)
# Requirement already satisfied: pytz>=2020.1 in /root/venv/lib/python3.9/site-packages (from pandas->cdlib==0.4.0->-r ./requirements.txt (line 4)) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in /root/venv/lib/python3.9/site-packages (from pandas->cdlib==0.4.0->-r ./requirements.txt (line 4)) (2025.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /root/venv/lib/python3.9/site-packages (from pandas->cdlib==0.4.0->-r ./requirements.txt (line 4)) (2.9.0.post0)
# Requirement already satisfied: narwhals>=1.15.1 in /root/venv/lib/python3.9/site-packages (from plotly->cdlib==0.4.0->-r ./requirements.txt (line 4)) (1.38.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /root/venv/lib/python3.9/site-packages (from pooch->cdlib==0.4.0->-r ./requirements.txt (line 4)) (4.3.7)
# Collecting Levenshtein==0.27.1
#   Downloading levenshtein-0.27.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (160 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.8/160.8 kB 8.3 MB/s eta 0:00:00
# Collecting rapidfuzz<4.0.0,>=3.9.0
#   Downloading rapidfuzz-3.13.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 80.1 MB/s eta 0:00:00
# Requirement already satisfied: threadpoolctl>=2.0.0 in /root/venv/lib/python3.9/site-packages (from scikit-learn->cdlib==0.4.0->-r ./requirements.txt (line 4)) (3.6.0)
# Requirement already satisfied: joblib>=1.0.0 in /root/venv/lib/python3.9/site-packages (from scikit-learn->cdlib==0.4.0->-r ./requirements.txt (line 4)) (1.5.0)
# Collecting hf-xet<2.0.0,>=1.1.2
#   Downloading hf_xet-1.1.3-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 76.3 MB/s eta 0:00:00
# Requirement already satisfied: fsspec>=2023.5.0 in /toolkit-cache/0.2.23/python3.9/kernel-libs/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.30.0->transformers>=4.11.3->feel-it->-r ./requirements.txt (line 3)) (2024.6.1)
# Requirement already satisfied: contourpy>=1.0.1 in /root/venv/lib/python3.9/site-packages (from matplotlib->bimlpa->cdlib==0.4.0->-r ./requirements.txt (line 4)) (1.3.0)
# Requirement already satisfied: fonttools>=4.22.0 in /root/venv/lib/python3.9/site-packages (from matplotlib->bimlpa->cdlib==0.4.0->-r ./requirements.txt (line 4)) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /root/venv/lib/python3.9/site-packages (from matplotlib->bimlpa->cdlib==0.4.0->-r ./requirements.txt (line 4)) (1.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /root/venv/lib/python3.9/site-packages (from matplotlib->bimlpa->cdlib==0.4.0->-r ./requirements.txt (line 4)) (11.2.1)
# Requirement already satisfied: cycler>=0.10 in /root/venv/lib/python3.9/site-packages (from matplotlib->bimlpa->cdlib==0.4.0->-r ./requirements.txt (line 4)) (0.12.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /root/venv/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client->-r ./requirements.txt (line 1)) (0.6.1)
# Requirement already satisfied: six>=1.5 in /root/venv/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas->cdlib==0.4.0->-r ./requirements.txt (line 4)) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /root/venv/lib/python3.9/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client->-r ./requirements.txt (line 1)) (3.4.2)
# Requirement already satisfied: certifi>=2017.4.17 in /root/venv/lib/python3.9/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client->-r ./requirements.txt (line 1)) (2025.4.26)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /root/venv/lib/python3.9/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client->-r ./requirements.txt (line 1)) (1.26.20)
# Requirement already satisfied: idna<4,>=2.5 in /root/venv/lib/python3.9/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client->-r ./requirements.txt (line 1)) (3.10)
# Building wheels for collected packages: python-louvain
#   Building wheel for python-louvain (setup.py): started
#   Building wheel for python-louvain (setup.py): finished with status 'done'
#   Created wheel for python-louvain: filename=python_louvain-0.16-py3-none-any.whl size=9458 sha256=8f05912fdf1befc1a7f90adbb15baf0939cf933c7280b3244e58ae94b283b05f
#   Stored in directory: /root/.cache/pip/wheels/4d/7c/b6/79b198e4ec43f915fbdf967953d48b89a18893b12aa9df0ae2
# Successfully built python-louvain
# Installing collected packages: texttable, uritemplate, scipy, safetensors, rapidfuzz, pulp, networkx, igraph, httplib2, hf-xet, thresholdclustering, python-louvain, python-igraph, pooch, Levenshtein, huggingface-hub, eva-lcd, dynetx, demon, tokenizers, python-Levenshtein, google-auth-httplib2, bimlpa, angelcommunity, transformers, google-api-python-client, cdlib, feel-it
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.9.3
#     Uninstalling scipy-1.9.3:
#       Successfully uninstalled scipy-1.9.3
# Successfully installed Levenshtein-0.27.1 angelcommunity-2.0.0 bimlpa-0.1.2 cdlib-0.4.0 demon-2.0.6 dynetx-0.3.2 eva-lcd-0.1.1 feel-it-1.0.5 google-api-python-client-2.172.0 google-auth-httplib2-0.2.0 hf-xet-1.1.3 httplib2-0.22.0 huggingface-hub-0.33.0 igraph-0.11.9 networkx-3.2.1 pooch-1.8.2 pulp-3.2.1 python-Levenshtein-0.27.1 python-igraph-0.11.9 python-louvain-0.16 rapidfuzz-3.13.0 safetensors-0.5.3 scipy-1.13.1 texttable-1.7.0 thresholdclustering-1.1 tokenizers-0.21.1 transformers-4.52.4 uritemplate-4.2.0
#
# [notice] A new release of pip is available: 23.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
